# %% [markdown]
# # Feature Engineering
#
# Construção da feature store com janelas temporais.

# %%
import sys; sys.path.insert(0, '..')

# %%
from src.features.build_features import merge_tables, build_temporal_features, save_feature_store
from src.features.macro_features import fetch_all_macro, merge_macro_features

# Merge das tabelas relacionais
df_merged = merge_tables()
print(f"Após merge: {df_merged.shape}")

# %%
# Feature engineering com janelas temporais
df_features = build_temporal_features(df_merged)
print(f"Com features temporais: {df_features.shape}")
df_features.head()

# %%
# Enriquecimento macroeconômico
macro = fetch_all_macro(cache=True)
print("Macro features:")
print(macro.tail())

# %%
# Persiste a feature store
save_feature_store(df_features)
print("Feature store salva!")
