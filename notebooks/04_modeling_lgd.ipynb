# %% [markdown]
# # Modelagem LGD — Regressão Beta
#
# Modelo separado do PD — custo de erro distinto.

# %%
import sys; sys.path.insert(0, '..')

# %%
from src.features.build_features import load_feature_store
from src.models.lgd_model import train_lgd, predict_lgd

df = load_feature_store()
model_lgd = train_lgd(df)

# %%
lgd_pred = predict_lgd(model_lgd, df)
import pandas as pd
print(pd.Series(lgd_pred).describe())
